# %% [markdown]
# <a href="https://colab.research.google.com/github/Sharon-Kairu/Linear-regression/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Linear Regression

# %%
import pandas as pd

# %%
nyc=pd.read_csv("/content/ave_hi_nyc_jan_1895-2018.csv", header='infer')
nyc
# Out:
#        Date  Value  Anomaly
# 0    189501   34.2     -3.2
# 1    189601   34.7     -2.7
# 2    189701   35.5     -1.9
# 3    189801   39.6      2.2
# 4    189901   36.4     -1.0
# ..      ...    ...      ...
# 119  201401   35.5     -1.9
# 120  201501   36.1     -1.3
# 121  201601   40.8      3.4
# 122  201701   42.8      5.4
# 123  201801   38.7      1.3
#
# [124 rows x 3 columns]

# %%
nyc.columns
# Out:
# Index(['Date', 'Value', 'Anomaly'], dtype='object')

# %%
nyc.colums=['Date','Temperature','Anomaly']
nyc.head(6)
# Out:
# <ipython-input-43-0864a7e7ad4b>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   nyc.colums=['Date','Temperature','Anomaly']
#      Date  Value  Anomaly
# 0  189501   34.2     -3.2
# 1  189601   34.7     -2.7
# 2  189701   35.5     -1.9
# 3  189801   39.6      2.2
# 4  189901   36.4     -1.0
# 5  190001   37.4      0.0

# %%
nyc.sample(5)
# Out:
#       Date  Value  Anomaly
# 98  199301   41.0      3.6
# 82  197701   26.1    -11.3
# 7   190201   35.0     -2.4
# 52  194701   43.0      5.6
# 49  194401   39.0      1.6

# %%
nyc.tail(5)
# Out:
#        Date  Value  Anomaly
# 119  201401   35.5     -1.9
# 120  201501   36.1     -1.3
# 121  201601   40.8      3.4
# 122  201701   42.8      5.4
# 123  201801   38.7      1.3

# %%
nyc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     124 non-null    int64
#  1   Value    124 non-null    float64
#  2   Anomaly  124 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 3.0 KB

# %%
nyc.Date=nyc.Date.floordiv(100)
nyc.head()
# Out:
#    Date  Value  Anomaly
# 0  1895   34.2     -3.2
# 1  1896   34.7     -2.7
# 2  1897   35.5     -1.9
# 3  1898   39.6      2.2
# 4  1899   36.4     -1.0

# %% [markdown]
# #Temperature=m*Date+c

# %%
from sklearn.model_selection import train_test_split

# %%
nyc['Date'].values
# Out:
# array([1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905,
#        1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916,
#        1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927,
#        1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938,
#        1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949,
#        1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960,
#        1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971,
#        1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982,
#        1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993,
#        1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004,
#        2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017, 2018])

# %%
X = nyc[['Date']].values  # Use double brackets to ensure 'Date' is treated as a DataFrame
y = nyc['Value'].values

# Split the data
X_train, X_test, y_train, y_test = train_test_split(nyc.Date.values.reshape(-1, 1), nyc.Value.values.reshape(-1,1), random_state=104)

# %%
y_test.shape
# Out:
# (31, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_regression = LinearRegression()
linear_regression
# Out:
# LinearRegression()

# %%
linear_regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
linear_regression.coef_
# Out:
# array([[0.00692337]])

# %%
#Value=0.83039216 -21.385294117647042

# %%
linear_regression.intercept_
# Out:
# array([24.503828])

# %%
0.70710814*2098- 21.385294117647042
# Out:
# 1462.127583602353

# %%
predicted = linear_regression.predict(X_test)
predicted
# Out:
# array([[38.40596258],
#        [37.97671341],
#        [38.135951  ],
#        [38.46827294],
#        [38.39211583],
#        [37.90747967],
#        [38.11518088],
#        [37.63746809],
#        [38.08056401],
#        [37.67208496],
#        [37.93517316],
#        [38.24672498],
#        [37.94209654],
#        [37.96979003],
#        [37.76208882],
#        [37.83132256],
#        [38.09441076],
#        [37.92824979],
#        [38.34365222],
#        [38.19133799],
#        [38.19826137],
#        [38.26057173],
#        [37.86593942],
#        [37.99748353],
#        [38.04594714],
#        [38.41288595],
#        [37.77593557],
#        [37.7413187 ],
#        [38.33672884],
#        [38.21210811],
#        [38.14287438]])

# %%
predicted=(lambda date: linear_regression.coef_*date+linear_regression.intercept_)(2030)
predicted
# Out:
# array([[38.5582768]])

# %% [markdown]
# 80:20,50:50,90:10,75:25- ROOT MEAN SQUARE FOR EACH. RMSE

# %%
import seaborn as sns

# %%
axes=sns.scatterplot(data=nyc,x='Date',y='Value',hue='Date',palette='winter',legend=False)
axes.set_ylim(10,70)
import numpy as np
x=np.array([min(nyc.Date.values),max(nyc.Date.values)])
y=predicted(x)
import matplotlib.pyplot as plt
line=plt.plot(x,y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-bef06006e9ed> in <cell line: 5>()
#       3 import numpy as np
#       4 x=np.array([min(nyc.Date.values),max(nyc.Date.values)])
# ----> 5 y=predicted(x)
#       6 import matplotlib.pyplot as plt
#       7 line=plt.plot(x,y)
#
# TypeError: 'numpy.ndarray' object is not callable
